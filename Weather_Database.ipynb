# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []


# Identify nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 742

# %%
# Import the requests library.
import requests

# Import the time library.
import time

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aksarka
# Processing Record 2 of Set 1 | roald
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | ponta do sol
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | laurel
# Processing Record 10 of Set 1 | katsuura
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | hilo
# Processing Record 14 of Set 1 | road town
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 1 | gueret
# Processing Record 19 of Set 1 | san quintin
# Processing Record 20 of Set 1 | vestmannaeyjar
# Processing Record 21 of Set 1 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 1 | punta arenas
# Processing Record 23 of Set 1 | bonavista
# Processing Record 24 of Set 1 | samarai
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | camana
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | pemangkat
# Processing Record 29 of Set 1 | lebu
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | port hedland
# Processing Record 32 of Set 1 | kodiak
# Processing Record 33 of Set 1 | barrow
# Processing Record 34 of Set 1 | miranorte
# City not found. Skipping...
# Processing Record 35 of Set 1 | mount gambier
# Processing Record 36 of Set 1 | bluff
# Processing Record 37 of Set 1 | santa cruz del sur
# Processing Record 38 of Set 1 | kaitangata
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 1 | laguna
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | airai
# Processing Record 44 of Set 1 | puerto escondido
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | nador
# Processing Record 47 of Set 1 | mao
# Processing Record 48 of Set 1 | khatanga
# Processing Record 49 of Set 1 | ribeira grande
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | seabra
# Processing Record 2 of Set 2 | chuy
# Processing Record 3 of Set 2 | fukue
# Processing Record 4 of Set 2 | ilulissat
# Processing Record 5 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 2 | athabasca
# Processing Record 8 of Set 2 | tay ninh
# Processing Record 9 of Set 2 | dakar
# Processing Record 10 of Set 2 | souillac
# Processing Record 11 of Set 2 | cayenne
# Processing Record 12 of Set 2 | kharan
# Processing Record 13 of Set 2 | victoria
# Processing Record 14 of Set 2 | georgetown
# Processing Record 15 of Set 2 | wajir
# Processing Record 16 of Set 2 | sioux lookout
# Processing Record 17 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 2 | wajima
# Processing Record 19 of Set 2 | mataura
# Processing Record 20 of Set 2 | yerbogachen
# Processing Record 21 of Set 2 | nalut
# Processing Record 22 of Set 2 | leh
# Processing Record 23 of Set 2 | tiruvottiyur
# City not found. Skipping...
# Processing Record 24 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 2 | mackenzie
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | helong
# Processing Record 28 of Set 2 | edd
# Processing Record 29 of Set 2 | namibe
# Processing Record 30 of Set 2 | norman wells
# Processing Record 31 of Set 2 | vao
# Processing Record 32 of Set 2 | waterloo
# Processing Record 33 of Set 2 | ijaki
# City not found. Skipping...
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | college
# Processing Record 36 of Set 2 | himora
# City not found. Skipping...
# Processing Record 37 of Set 2 | butaritari
# Processing Record 38 of Set 2 | vaini
# Processing Record 39 of Set 2 | codrington
# Processing Record 40 of Set 2 | pero pinheiro
# Processing Record 41 of Set 2 | clyde river
# Processing Record 42 of Set 2 | florianopolis
# Processing Record 43 of Set 2 | sisimiut
# Processing Record 44 of Set 2 | nanortalik
# Processing Record 45 of Set 2 | saint-georges
# Processing Record 46 of Set 2 | aban
# Processing Record 47 of Set 2 | byron bay
# Processing Record 48 of Set 2 | paraiso
# Processing Record 49 of Set 2 | grindavik
# Processing Record 50 of Set 2 | matai
# Processing Record 1 of Set 3 | svetlyy
# Processing Record 2 of Set 3 | teya
# Processing Record 3 of Set 3 | kruisfontein
# Processing Record 4 of Set 3 | iqaluit
# Processing Record 5 of Set 3 | anastacio
# Processing Record 6 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 3 | vicuna
# Processing Record 8 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 3 | paamiut
# Processing Record 10 of Set 3 | pecos
# Processing Record 11 of Set 3 | cedar city
# Processing Record 12 of Set 3 | bahia honda
# Processing Record 13 of Set 3 | christchurch
# Processing Record 14 of Set 3 | bilma
# Processing Record 15 of Set 3 | port alfred
# Processing Record 16 of Set 3 | port-gentil
# Processing Record 17 of Set 3 | verkhnyaya inta
# Processing Record 18 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 3 | geraldton
# Processing Record 20 of Set 3 | luderitz
# Processing Record 21 of Set 3 | villa bruzual
# Processing Record 22 of Set 3 | yoichi
# Processing Record 23 of Set 3 | kawalu
# Processing Record 24 of Set 3 | irbeyskoye
# Processing Record 25 of Set 3 | pevek
# Processing Record 26 of Set 3 | yellowknife
# Processing Record 27 of Set 3 | nagorsk
# Processing Record 28 of Set 3 | launceston
# Processing Record 29 of Set 3 | wichita falls
# Processing Record 30 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 3 | broome
# Processing Record 32 of Set 3 | korla
# Processing Record 33 of Set 3 | san patricio
# Processing Record 34 of Set 3 | ust-shonosha
# Processing Record 35 of Set 3 | margate
# Processing Record 36 of Set 3 | sorland
# Processing Record 37 of Set 3 | avarua
# Processing Record 38 of Set 3 | lavrentiya
# Processing Record 39 of Set 3 | nantucket
# Processing Record 40 of Set 3 | hami
# Processing Record 41 of Set 3 | bambous virieux
# Processing Record 42 of Set 3 | coihaique
# Processing Record 43 of Set 3 | honningsvag
# Processing Record 44 of Set 3 | esperance
# Processing Record 45 of Set 3 | kangasala
# Processing Record 46 of Set 3 | castro
# Processing Record 47 of Set 3 | sakakah
# Processing Record 48 of Set 3 | qaanaaq
# Processing Record 49 of Set 3 | aklavik
# Processing Record 50 of Set 3 | namatanai
# Processing Record 1 of Set 4 | sharan
# Processing Record 2 of Set 4 | pisco
# Processing Record 3 of Set 4 | amatan
# Processing Record 4 of Set 4 | narsaq
# Processing Record 5 of Set 4 | marzuq
# Processing Record 6 of Set 4 | toshkivka
# Processing Record 7 of Set 4 | antofagasta
# Processing Record 8 of Set 4 | illapel
# Processing Record 9 of Set 4 | half moon bay
# Processing Record 10 of Set 4 | faanui
# Processing Record 11 of Set 4 | warrington
# Processing Record 12 of Set 4 | rantoul
# Processing Record 13 of Set 4 | eureka
# Processing Record 14 of Set 4 | nome
# Processing Record 15 of Set 4 | porto novo
# Processing Record 16 of Set 4 | hithadhoo
# Processing Record 17 of Set 4 | bubaque
# Processing Record 18 of Set 4 | avallon
# Processing Record 19 of Set 4 | longyearbyen
# Processing Record 20 of Set 4 | sinnamary
# Processing Record 21 of Set 4 | rocha
# Processing Record 22 of Set 4 | turukhansk
# Processing Record 23 of Set 4 | egvekinot
# Processing Record 24 of Set 4 | kavaratti
# Processing Record 25 of Set 4 | faya
# Processing Record 26 of Set 4 | kirakira
# Processing Record 27 of Set 4 | omboue
# Processing Record 28 of Set 4 | sibolga
# Processing Record 29 of Set 4 | mpika
# Processing Record 30 of Set 4 | gornyak
# Processing Record 31 of Set 4 | dingle
# Processing Record 32 of Set 4 | malartic
# Processing Record 33 of Set 4 | krasnoselkup
# Processing Record 34 of Set 4 | nouakchott
# Processing Record 35 of Set 4 | boueni
# Processing Record 36 of Set 4 | ketchikan
# Processing Record 37 of Set 4 | saint george
# Processing Record 38 of Set 4 | lompoc
# Processing Record 39 of Set 4 | balkanabat
# Processing Record 40 of Set 4 | tete
# Processing Record 41 of Set 4 | santa vitoria do palmar
# Processing Record 42 of Set 4 | chapais
# Processing Record 43 of Set 4 | saldanha
# Processing Record 44 of Set 4 | talnakh
# Processing Record 45 of Set 4 | coquimbo
# Processing Record 46 of Set 4 | ceres
# Processing Record 47 of Set 4 | ginda
# Processing Record 48 of Set 4 | berlevag
# Processing Record 49 of Set 4 | haines junction
# Processing Record 50 of Set 4 | saint-philippe
# Processing Record 1 of Set 5 | muros
# Processing Record 2 of Set 5 | zyryanka
# Processing Record 3 of Set 5 | bathsheba
# Processing Record 4 of Set 5 | ocampo
# Processing Record 5 of Set 5 | tura
# Processing Record 6 of Set 5 | narimanov
# Processing Record 7 of Set 5 | pousat
# City not found. Skipping...
# Processing Record 8 of Set 5 | port blair
# Processing Record 9 of Set 5 | preston
# Processing Record 10 of Set 5 | vrangel
# Processing Record 11 of Set 5 | khandyga
# Processing Record 12 of Set 5 | nikolskoye
# Processing Record 13 of Set 5 | bethel
# Processing Record 14 of Set 5 | carutapera
# Processing Record 15 of Set 5 | dikson
# Processing Record 16 of Set 5 | clearwater
# Processing Record 17 of Set 5 | asau
# Processing Record 18 of Set 5 | thompson
# Processing Record 19 of Set 5 | nong chik
# Processing Record 20 of Set 5 | altamont
# Processing Record 21 of Set 5 | kama
# Processing Record 22 of Set 5 | dehloran
# Processing Record 23 of Set 5 | provideniya
# Processing Record 24 of Set 5 | amga
# Processing Record 25 of Set 5 | mahdalynivka
# Processing Record 26 of Set 5 | hovd
# Processing Record 27 of Set 5 | enshi
# Processing Record 28 of Set 5 | naco
# Processing Record 29 of Set 5 | tuatapere
# Processing Record 30 of Set 5 | kapit
# Processing Record 31 of Set 5 | kyra
# Processing Record 32 of Set 5 | dudinka
# Processing Record 33 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 34 of Set 5 | valmiera
# Processing Record 35 of Set 5 | ray
# Processing Record 36 of Set 5 | paducah
# Processing Record 37 of Set 5 | tapejara
# Processing Record 38 of Set 5 | avera
# Processing Record 39 of Set 5 | cururupu
# Processing Record 40 of Set 5 | mahebourg
# Processing Record 41 of Set 5 | mar del plata
# Processing Record 42 of Set 5 | tateyama
# Processing Record 43 of Set 5 | tuktoyaktuk
# Processing Record 44 of Set 5 | chumikan
# Processing Record 45 of Set 5 | wageningen
# Processing Record 46 of Set 5 | tevaitoa
# Processing Record 47 of Set 5 | leshukonskoye
# Processing Record 48 of Set 5 | kirgiz-miyaki
# Processing Record 49 of Set 5 | quatre cocos
# Processing Record 50 of Set 5 | sur
# Processing Record 1 of Set 6 | mehamn
# Processing Record 2 of Set 6 | klaksvik
# Processing Record 3 of Set 6 | denpasar
# Processing Record 4 of Set 6 | guerrero negro
# Processing Record 5 of Set 6 | luis correia
# Processing Record 6 of Set 6 | touros
# Processing Record 7 of Set 6 | mildura
# Processing Record 8 of Set 6 | puerto cabezas
# Processing Record 9 of Set 6 | bonthe
# Processing Record 10 of Set 6 | necochea
# Processing Record 11 of Set 6 | awbari
# Processing Record 12 of Set 6 | huarmey
# Processing Record 13 of Set 6 | petrozavodsk
# Processing Record 14 of Set 6 | vostok
# Processing Record 15 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 16 of Set 6 | inuvik
# Processing Record 17 of Set 6 | novo oriente
# Processing Record 18 of Set 6 | toora-khem
# Processing Record 19 of Set 6 | sabya
# Processing Record 20 of Set 6 | ewa beach
# Processing Record 21 of Set 6 | nautla
# Processing Record 22 of Set 6 | timra
# Processing Record 23 of Set 6 | camalu
# Processing Record 24 of Set 6 | chokurdakh
# Processing Record 25 of Set 6 | uusikaupunki
# Processing Record 26 of Set 6 | husavik
# Processing Record 27 of Set 6 | los llanos de aridane
# Processing Record 28 of Set 6 | vila franca do campo
# Processing Record 29 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 6 | ciparay
# Processing Record 32 of Set 6 | taoudenni
# Processing Record 33 of Set 6 | mocuba
# Processing Record 34 of Set 6 | hobyo
# Processing Record 35 of Set 6 | shakhtinsk
# Processing Record 36 of Set 6 | richards bay
# Processing Record 37 of Set 6 | ancud
# Processing Record 38 of Set 6 | harper
# Processing Record 39 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 6 | ust-nera
# Processing Record 41 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 6 | granadilla de abona
# Processing Record 43 of Set 6 | ulaangom
# Processing Record 44 of Set 6 | moussoro
# Processing Record 45 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 46 of Set 6 | mbaiki
# Processing Record 47 of Set 6 | boda
# Processing Record 48 of Set 6 | alvand
# Processing Record 49 of Set 6 | cherskiy
# Processing Record 50 of Set 6 | djang
# City not found. Skipping...
# Processing Record 1 of Set 7 | chicama
# Processing Record 2 of Set 7 | maryville
# Processing Record 3 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 7 | iralaya
# Processing Record 5 of Set 7 | ordzhonikidze
# Processing Record 6 of Set 7 | tautira
# Processing Record 7 of Set 7 | olinda
# Processing Record 8 of Set 7 | fortuna
# Processing Record 9 of Set 7 | saskylakh
# Processing Record 10 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 11 of Set 7 | baykit
# Processing Record 12 of Set 7 | saint anthony
# Processing Record 13 of Set 7 | bengkulu
# Processing Record 14 of Set 7 | ossora
# Processing Record 15 of Set 7 | emba
# Processing Record 16 of Set 7 | maceio
# Processing Record 17 of Set 7 | exu
# Processing Record 18 of Set 7 | port lincoln
# Processing Record 19 of Set 7 | mandalgovi
# Processing Record 20 of Set 7 | praia
# Processing Record 21 of Set 7 | chernyshevskiy
# Processing Record 22 of Set 7 | erenhot
# Processing Record 23 of Set 7 | voh
# Processing Record 24 of Set 7 | balta
# Processing Record 25 of Set 7 | erdenet
# Processing Record 26 of Set 7 | hirtshals
# Processing Record 27 of Set 7 | vera cruz
# Processing Record 28 of Set 7 | carrboro
# Processing Record 29 of Set 7 | sao filipe
# Processing Record 30 of Set 7 | khor
# Processing Record 31 of Set 7 | kikwit
# Processing Record 32 of Set 7 | katangli
# Processing Record 33 of Set 7 | guiyang
# Processing Record 34 of Set 7 | ilebo
# Processing Record 35 of Set 7 | vernon
# Processing Record 36 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 7 | verkhnevilyuysk
# Processing Record 39 of Set 7 | tiksi
# Processing Record 40 of Set 7 | lasa
# Processing Record 41 of Set 7 | brae
# Processing Record 42 of Set 7 | leningradskiy
# Processing Record 43 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 7 | marfino
# Processing Record 45 of Set 7 | port hardy
# Processing Record 46 of Set 7 | solwezi
# Processing Record 47 of Set 7 | trinidad
# Processing Record 48 of Set 7 | auki
# Processing Record 49 of Set 7 | tsumeb
# Processing Record 50 of Set 7 | sao joao da barra
# Processing Record 1 of Set 8 | mabaruma
# Processing Record 2 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 3 of Set 8 | kindu
# Processing Record 4 of Set 8 | okahandja
# Processing Record 5 of Set 8 | eyl
# Processing Record 6 of Set 8 | villazon
# Processing Record 7 of Set 8 | hamilton
# Processing Record 8 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 9 of Set 8 | sabang
# Processing Record 10 of Set 8 | bara
# Processing Record 11 of Set 8 | hope
# Processing Record 12 of Set 8 | bacolod
# Processing Record 13 of Set 8 | aleksandrovskoye
# Processing Record 14 of Set 8 | bardiyah
# Processing Record 15 of Set 8 | barra patuca
# Processing Record 16 of Set 8 | havre-saint-pierre
# Processing Record 17 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 18 of Set 8 | batemans bay
# Processing Record 19 of Set 8 | tiarei
# Processing Record 20 of Set 8 | havoysund
# Processing Record 21 of Set 8 | kargasok
# Processing Record 22 of Set 8 | barra do garcas
# Processing Record 23 of Set 8 | maarianhamina
# Processing Record 24 of Set 8 | arraial do cabo
# Processing Record 25 of Set 8 | moranbah
# Processing Record 26 of Set 8 | seoul
# Processing Record 27 of Set 8 | omaruru
# Processing Record 28 of Set 8 | hasaki
# Processing Record 29 of Set 8 | upernavik
# Processing Record 30 of Set 8 | hay river
# Processing Record 31 of Set 8 | lensk
# Processing Record 32 of Set 8 | yeppoon
# Processing Record 33 of Set 8 | lovington
# Processing Record 34 of Set 8 | planaltina
# Processing Record 35 of Set 8 | cedar park
# Processing Record 36 of Set 8 | plunge
# Processing Record 37 of Set 8 | matara
# Processing Record 38 of Set 8 | iglesias
# Processing Record 39 of Set 8 | agua verde
# Processing Record 40 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 8 | tuban
# Processing Record 42 of Set 8 | rorvik
# Processing Record 43 of Set 8 | west wendover
# Processing Record 44 of Set 8 | nyurba
# Processing Record 45 of Set 8 | nha trang
# Processing Record 46 of Set 8 | comodoro rivadavia
# Processing Record 47 of Set 8 | mawlaik
# Processing Record 48 of Set 8 | san policarpo
# Processing Record 49 of Set 8 | gravdal
# Processing Record 50 of Set 8 | pangnirtung
# Processing Record 1 of Set 9 | kavieng
# Processing Record 2 of Set 9 | san cristobal
# Processing Record 3 of Set 9 | kilindoni
# Processing Record 4 of Set 9 | ariyalur
# Processing Record 5 of Set 9 | fonte boa
# Processing Record 6 of Set 9 | gisborne
# Processing Record 7 of Set 9 | tashtagol
# Processing Record 8 of Set 9 | tadine
# Processing Record 9 of Set 9 | ekimchan
# Processing Record 10 of Set 9 | port-cartier
# Processing Record 11 of Set 9 | atar
# Processing Record 12 of Set 9 | kuytun
# Processing Record 13 of Set 9 | sitka
# Processing Record 14 of Set 9 | aloleng
# Processing Record 15 of Set 9 | mana
# Processing Record 16 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 9 | anadyr
# Processing Record 18 of Set 9 | severo-kurilsk
# Processing Record 19 of Set 9 | puerto gaitan
# Processing Record 20 of Set 9 | henties bay
# Processing Record 21 of Set 9 | east london
# Processing Record 22 of Set 9 | praia da vitoria
# Processing Record 23 of Set 9 | vilyuysk
# Processing Record 24 of Set 9 | mosetse
# Processing Record 25 of Set 9 | kankavli
# City not found. Skipping...
# Processing Record 26 of Set 9 | saint-augustin
# Processing Record 27 of Set 9 | dzaoudzi
# Processing Record 28 of Set 9 | mitsamiouli
# Processing Record 29 of Set 9 | sakaiminato
# Processing Record 30 of Set 9 | kahului
# Processing Record 31 of Set 9 | mattru
# Processing Record 32 of Set 9 | gua musang
# Processing Record 33 of Set 9 | cabadiangan
# Processing Record 34 of Set 9 | lagoa
# Processing Record 35 of Set 9 | mansehra
# Processing Record 36 of Set 9 | aksu
# Processing Record 37 of Set 9 | cuxhaven
# Processing Record 38 of Set 9 | dembi dolo
# Processing Record 39 of Set 9 | acapulco
# Processing Record 40 of Set 9 | constitucion
# Processing Record 41 of Set 9 | dongli
# Processing Record 42 of Set 9 | takoradi
# Processing Record 43 of Set 9 | mount isa
# Processing Record 44 of Set 9 | betafo
# Processing Record 45 of Set 9 | jutai
# Processing Record 46 of Set 9 | maragogi
# Processing Record 47 of Set 9 | petropavl
# Processing Record 48 of Set 9 | halifax
# Processing Record 49 of Set 9 | rawlins
# Processing Record 50 of Set 9 | te anau
# Processing Record 1 of Set 10 | oros
# Processing Record 2 of Set 10 | torbay
# Processing Record 3 of Set 10 | sosnovo-ozerskoye
# Processing Record 4 of Set 10 | tamworth
# Processing Record 5 of Set 10 | haibowan
# City not found. Skipping...
# Processing Record 6 of Set 10 | shelburne
# Processing Record 7 of Set 10 | thunder bay
# Processing Record 8 of Set 10 | portland
# Processing Record 9 of Set 10 | suez
# Processing Record 10 of Set 10 | bam
# Processing Record 11 of Set 10 | riyadh
# Processing Record 12 of Set 10 | vila velha
# Processing Record 13 of Set 10 | kralendijk
# Processing Record 14 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 15 of Set 10 | parrita
# Processing Record 16 of Set 10 | darhan
# Processing Record 17 of Set 10 | kualakapuas
# Processing Record 18 of Set 10 | apricena
# Processing Record 19 of Set 10 | spasskoye
# Processing Record 20 of Set 10 | balikpapan
# Processing Record 21 of Set 10 | doembang nangbuat
# Processing Record 22 of Set 10 | waddan
# Processing Record 23 of Set 10 | kloulklubed
# Processing Record 24 of Set 10 | salinopolis
# Processing Record 25 of Set 10 | bure
# Processing Record 26 of Set 10 | kokoda
# Processing Record 27 of Set 10 | castiglion fiorentino
# Processing Record 28 of Set 10 | santa cruz
# Processing Record 29 of Set 10 | sao francisco
# Processing Record 30 of Set 10 | bela
# Processing Record 31 of Set 10 | ostrovnoy
# Processing Record 32 of Set 10 | kununurra
# Processing Record 33 of Set 10 | sitniki
# Processing Record 34 of Set 10 | ojinaga
# Processing Record 35 of Set 10 | shasta lake
# Processing Record 36 of Set 10 | evensk
# Processing Record 37 of Set 10 | la asuncion
# Processing Record 38 of Set 10 | storsteinnes
# Processing Record 39 of Set 10 | svetlogorsk
# Processing Record 40 of Set 10 | alor setar
# Processing Record 41 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 10 | maniitsoq
# Processing Record 43 of Set 10 | losinyy
# Processing Record 44 of Set 10 | ulsteinvik
# Processing Record 45 of Set 10 | melilla
# Processing Record 46 of Set 10 | mbandaka
# Processing Record 47 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 48 of Set 10 | oranjemund
# Processing Record 49 of Set 10 | madera
# Processing Record 50 of Set 10 | ambon
# Processing Record 1 of Set 11 | galle
# Processing Record 2 of Set 11 | kwinana
# Processing Record 3 of Set 11 | saryshagan
# City not found. Skipping...
# Processing Record 4 of Set 11 | puerto madryn
# Processing Record 5 of Set 11 | muscatine
# Processing Record 6 of Set 11 | antalaha
# Processing Record 7 of Set 11 | santiago
# Processing Record 8 of Set 11 | houma
# Processing Record 9 of Set 11 | petatlan
# Processing Record 10 of Set 11 | vanavara
# Processing Record 11 of Set 11 | buqayq
# City not found. Skipping...
# Processing Record 12 of Set 11 | port keats
# Processing Record 13 of Set 11 | cabo san lucas
# Processing Record 14 of Set 11 | emerald
# Processing Record 15 of Set 11 | maningrida
# Processing Record 16 of Set 11 | tavda
# Processing Record 17 of Set 11 | crossville
# Processing Record 18 of Set 11 | balykshi
# Processing Record 19 of Set 11 | simav
# Processing Record 20 of Set 11 | qax
# Processing Record 21 of Set 11 | cidreira
# Processing Record 22 of Set 11 | likhoslavl
# Processing Record 23 of Set 11 | fayaoue
# Processing Record 24 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 11 | inyonga
# Processing Record 26 of Set 11 | manokwari
# Processing Record 27 of Set 11 | vezirkopru
# Processing Record 28 of Set 11 | madison
# Processing Record 29 of Set 11 | stutterheim
# Processing Record 30 of Set 11 | nagua
# Processing Record 31 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 11 | qurayyat
# Processing Record 33 of Set 11 | hambantota
# Processing Record 34 of Set 11 | anchorage
# Processing Record 35 of Set 11 | qasigiannguit
# Processing Record 36 of Set 11 | nedjo
# Processing Record 37 of Set 11 | french harbor
# Processing Record 38 of Set 11 | cam ranh
# Processing Record 39 of Set 11 | waipawa
# Processing Record 40 of Set 11 | severomuysk
# Processing Record 41 of Set 11 | tessalit
# Processing Record 42 of Set 11 | fujin
# Processing Record 43 of Set 11 | chimbote
# Processing Record 44 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 45 of Set 11 | coffs harbour
# Processing Record 46 of Set 11 | natal
# Processing Record 47 of Set 11 | fuerte olimpo
# Processing Record 48 of Set 11 | lubbock
# Processing Record 49 of Set 11 | troitsko-pechorsk
# Processing Record 50 of Set 11 | catamarca
# Processing Record 1 of Set 12 | lahij
# Processing Record 2 of Set 12 | pacific grove
# Processing Record 3 of Set 12 | belmonte
# Processing Record 4 of Set 12 | wucheng
# Processing Record 5 of Set 12 | fenoarivo atsinanana
# Processing Record 6 of Set 12 | biscarrosse
# Processing Record 7 of Set 12 | beringovskiy
# Processing Record 8 of Set 12 | kangaba
# Processing Record 9 of Set 12 | kaliyaganj
# Processing Record 10 of Set 12 | whitianga
# Processing Record 11 of Set 12 | ankazobe
# Processing Record 12 of Set 12 | lyantonde
# Processing Record 13 of Set 12 | naze
# Processing Record 14 of Set 12 | guelengdeng
# City not found. Skipping...
# Processing Record 15 of Set 12 | karratha
# Processing Record 16 of Set 12 | aleksandrov gay
# Processing Record 17 of Set 12 | makakilo city
# Processing Record 18 of Set 12 | jiangyou
# Processing Record 19 of Set 12 | port macquarie
# Processing Record 20 of Set 12 | atambua
# Processing Record 21 of Set 12 | savonlinna
# Processing Record 22 of Set 12 | hualmay
# Processing Record 23 of Set 12 | gollere
# City not found. Skipping...
# Processing Record 24 of Set 12 | skoghall
# Processing Record 25 of Set 12 | alice
# Processing Record 26 of Set 12 | homer
# Processing Record 27 of Set 12 | lerwick
# Processing Record 28 of Set 12 | popondetta
# Processing Record 29 of Set 12 | porto belo
# Processing Record 30 of Set 12 | mazamari
# Processing Record 31 of Set 12 | huilong
# Processing Record 32 of Set 12 | sungairaya
# Processing Record 33 of Set 12 | trincomalee
# Processing Record 34 of Set 12 | fairlie
# Processing Record 35 of Set 12 | caravelas
# Processing Record 36 of Set 12 | bambanglipuro
# Processing Record 37 of Set 12 | biak
# Processing Record 38 of Set 12 | paso de los toros
# Processing Record 39 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 12 | masuguru
# Processing Record 41 of Set 12 | monrovia
# Processing Record 42 of Set 12 | harer
# Processing Record 43 of Set 12 | belgrade
# Processing Record 44 of Set 12 | taltal
# Processing Record 45 of Set 12 | akureyri
# Processing Record 46 of Set 12 | careiro da varzea
# Processing Record 47 of Set 12 | puerto colombia
# Processing Record 48 of Set 12 | darab
# Processing Record 49 of Set 12 | agropoli
# Processing Record 50 of Set 12 | alofi
# Processing Record 1 of Set 13 | abdanan
# Processing Record 2 of Set 13 | hat yai
# Processing Record 3 of Set 13 | moses lake
# Processing Record 4 of Set 13 | ampanihy
# Processing Record 5 of Set 13 | itaobim
# Processing Record 6 of Set 13 | agadir
# Processing Record 7 of Set 13 | mareeba
# Processing Record 8 of Set 13 | zhigalovo
# Processing Record 9 of Set 13 | winnemucca
# Processing Record 10 of Set 13 | aniva
# Processing Record 11 of Set 13 | aksay
# Processing Record 12 of Set 13 | dunedin
# Processing Record 13 of Set 13 | queanbeyan
# Processing Record 14 of Set 13 | alice springs
# Processing Record 15 of Set 13 | batagay-alyta
# Processing Record 16 of Set 13 | cape elizabeth
# City not found. Skipping...
# Processing Record 17 of Set 13 | prince rupert
# Processing Record 18 of Set 13 | gigmoto
# Processing Record 19 of Set 13 | dalvik
# Processing Record 20 of Set 13 | bandarbeyla
# Processing Record 21 of Set 13 | sooke
# Processing Record 22 of Set 13 | vargem grande
# Processing Record 23 of Set 13 | sulangan
# Processing Record 24 of Set 13 | nouadhibou
# Processing Record 25 of Set 13 | changde
# Processing Record 26 of Set 13 | porto santo
# Processing Record 27 of Set 13 | xochistlahuaca
# Processing Record 28 of Set 13 | goderich
# Processing Record 29 of Set 13 | ruston
# Processing Record 30 of Set 13 | kenora
# Processing Record 31 of Set 13 | aswan
# Processing Record 32 of Set 13 | isangel
# Processing Record 33 of Set 13 | piacabucu
# Processing Record 34 of Set 13 | ca mau
# Processing Record 35 of Set 13 | morant bay
# Processing Record 36 of Set 13 | dubrovnik
# Processing Record 37 of Set 13 | ikungi
# Processing Record 38 of Set 13 | teguldet
# Processing Record 39 of Set 13 | bundaberg
# Processing Record 40 of Set 13 | fort nelson
# Processing Record 41 of Set 13 | huron
# Processing Record 42 of Set 13 | cervo
# Processing Record 43 of Set 13 | mount pleasant
# Processing Record 44 of Set 13 | tongliao
# Processing Record 45 of Set 13 | esso
# Processing Record 46 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 47 of Set 13 | kambove
# Processing Record 48 of Set 13 | saint-joseph
# Processing Record 49 of Set 13 | kainantu
# Processing Record 50 of Set 13 | san juan
# Processing Record 1 of Set 14 | kvitok
# Processing Record 2 of Set 14 | abrau-dyurso
# Processing Record 3 of Set 14 | dauphin
# Processing Record 4 of Set 14 | yulara
# Processing Record 5 of Set 14 | dandong
# Processing Record 6 of Set 14 | dumingag
# Processing Record 7 of Set 14 | maumere
# Processing Record 8 of Set 14 | namasigue
# Processing Record 9 of Set 14 | saint-jean-port-joli
# Processing Record 10 of Set 14 | tutoia
# Processing Record 11 of Set 14 | mabai
# Processing Record 12 of Set 14 | peruibe
# Processing Record 13 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 14 of Set 14 | san jeronimo
# Processing Record 15 of Set 14 | salalah
# Processing Record 16 of Set 14 | hearst
# Processing Record 17 of Set 14 | paysandu
# Processing Record 18 of Set 14 | cap malheureux
# Processing Record 19 of Set 14 | hervey bay
# Processing Record 20 of Set 14 | conceicao do araguaia
# Processing Record 21 of Set 14 | banovce
# City not found. Skipping...
# Processing Record 22 of Set 14 | moree
# Processing Record 23 of Set 14 | nadym
# Processing Record 24 of Set 14 | srednekolymsk
# Processing Record 25 of Set 14 | ushtobe
# Processing Record 26 of Set 14 | erzincan
# Processing Record 27 of Set 14 | madimba
# Processing Record 28 of Set 14 | anisoc
# Processing Record 29 of Set 14 | lata
# Processing Record 30 of Set 14 | progreso
# Processing Record 31 of Set 14 | lorengau
# Processing Record 32 of Set 14 | sambava
# Processing Record 33 of Set 14 | banjar
# Processing Record 34 of Set 14 | saint paul
# Processing Record 35 of Set 14 | livingston
# Processing Record 36 of Set 14 | san rafael
# Processing Record 37 of Set 14 | qandala
# Processing Record 38 of Set 14 | flinders
# Processing Record 39 of Set 14 | ashland
# Processing Record 40 of Set 14 | gidam
# Processing Record 41 of Set 14 | coro
# Processing Record 42 of Set 14 | kamenka
# Processing Record 43 of Set 14 | olavarria
# Processing Record 44 of Set 14 | rawalpindi
# Processing Record 45 of Set 14 | mayo
# Processing Record 46 of Set 14 | bud
# Processing Record 47 of Set 14 | rosetown
# Processing Record 48 of Set 14 | taperoa
# Processing Record 49 of Set 14 | mananjary
# Processing Record 50 of Set 14 | inta
# Processing Record 1 of Set 15 | port augusta
# Processing Record 2 of Set 15 | pella
# Processing Record 3 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 15 | luze
# Processing Record 5 of Set 15 | lima
# Processing Record 6 of Set 15 | juba
# Processing Record 7 of Set 15 | svirstroy
# Processing Record 8 of Set 15 | scarborough
# Processing Record 9 of Set 15 | banda aceh
# Processing Record 10 of Set 15 | koumac
# Processing Record 11 of Set 15 | sungaipenuh
# Processing Record 12 of Set 15 | prince george
# Processing Record 13 of Set 15 | the valley
# Processing Record 14 of Set 15 | linxia
# Processing Record 15 of Set 15 | ukiah
# Processing Record 16 of Set 15 | koroni
# Processing Record 17 of Set 15 | north bend
# Processing Record 18 of Set 15 | tomatlan
# Processing Record 19 of Set 15 | sicuani
# Processing Record 20 of Set 15 | nicoya
# Processing Record 21 of Set 15 | khasan
# Processing Record 22 of Set 15 | luanda
# Processing Record 23 of Set 15 | sarti
# Processing Record 24 of Set 15 | lac du bonnet
# Processing Record 25 of Set 15 | tyumentsevo
# Processing Record 26 of Set 15 | weinan
# Processing Record 27 of Set 15 | aksarayskiy
# Processing Record 28 of Set 15 | nemuro
# Processing Record 29 of Set 15 | geresk
# City not found. Skipping...
# Processing Record 30 of Set 15 | severodvinsk
# Processing Record 31 of Set 15 | bassano
# Processing Record 32 of Set 15 | chinhoyi
# Processing Record 33 of Set 15 | black river
# Processing Record 34 of Set 15 | inirida
# Processing Record 35 of Set 15 | ahipara
# Processing Record 36 of Set 15 | teguise
# Processing Record 37 of Set 15 | sangar
# Processing Record 38 of Set 15 | broken hill
# Processing Record 39 of Set 15 | kuching
# Processing Record 40 of Set 15 | conroe
# Processing Record 41 of Set 15 | burgas
# Processing Record 42 of Set 15 | kodinsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 688

# %%
# Convert array of dictionaries to a pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(20)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0          Aksarka  66.5606   67.7975     66.15       broken clouds        28
# 1            Roald  62.5833    6.1333     49.75       broken clouds        81
# 2          Ushuaia -54.8000  -68.3000     33.46     overcast clouds        93
# 3           Hobart -42.8794  147.3294     58.86    scattered clouds        66
# 4     Ponta Do Sol  32.6667  -17.1000     66.83       broken clouds        68
# 5        Busselton -33.6500  115.3333     63.46          few clouds        61
# 6            Kapaa  22.0752 -159.3190     78.78          few clouds        80
# 7           Laurel  39.0993  -76.8483     65.66       broken clouds        96
# 8         Katsuura  35.1333  140.3000     70.66    scattered clouds        71
# 9     Puerto Ayora  -0.7393  -90.3518     69.55     overcast clouds        98
# 10        Tasiilaq  65.6145  -37.6368     41.16     overcast clouds        77
# 11            Hilo  19.7297 -155.0900     75.27     overcast clouds        87
# 12       Road Town  18.4167  -64.6167     78.89     overcast clouds        79
# 13     New Norfolk -42.7826  147.0587     58.50       broken clouds        78
# 14       Jamestown  42.0970  -79.2353     60.39                mist        94
# 15          Gueret  46.1667    1.8667     49.71     overcast clouds        89
# 16     San Quintin  30.4833 -115.9500     59.45          few clouds        87
# 17  Vestmannaeyjar  63.4427  -20.2734     48.24       broken clouds        83
# 18    Punta Arenas -53.1500  -70.9167     37.51           clear sky        65
# 19       Bonavista  48.6499  -53.1147     40.73     overcast clouds        83
#
#     Cloudiness  Wind Speed Country
# 0           61       18.32      RU
# 1           75       10.36      NO
# 2          100       27.63      AR
# 3           40        9.22      AU
# 4           57        3.87      PT
# 5           20       18.39      AU
# 6           20       10.36      US
# 7           75        4.61      US
# 8           39        9.24      JP
# 9           93        7.00      EC
# 10         100       13.02      GL
# 11         100        6.91      US
# 12         100       17.76      VG
# 13          83        1.01      AU
# 14         100        3.44      US
# 15          94        4.59      FR
# 16          12       10.58      MX
# 17          54       16.60      IS
# 18           0       18.41      CL
# 19         100        6.33      CA

# %%
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Aksarka      RU  66.5606   67.7975     66.15        28          61
# 1         Roald      NO  62.5833    6.1333     49.75        81          75
# 2       Ushuaia      AR -54.8000  -68.3000     33.46        93         100
# 3        Hobart      AU -42.8794  147.3294     58.86        66          40
# 4  Ponta Do Sol      PT  32.6667  -17.1000     66.83        68          57
# 5     Busselton      AU -33.6500  115.3333     63.46        61          20
# 6         Kapaa      US  22.0752 -159.3190     78.78        80          20
# 7        Laurel      US  39.0993  -76.8483     65.66        96          75
# 8      Katsuura      JP  35.1333  140.3000     70.66        71          39
# 9  Puerto Ayora      EC  -0.7393  -90.3518     69.55        98          93
#
#    Wind Speed Current Description
# 0       18.32       broken clouds
# 1       10.36       broken clouds
# 2       27.63     overcast clouds
# 3        9.22    scattered clouds
# 4        3.87       broken clouds
# 5       18.39          few clouds
# 6       10.36          few clouds
# 7        4.61       broken clouds
# 8        9.24    scattered clouds
# 9        7.00     overcast clouds

# %%
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %%
# Create the output File (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")

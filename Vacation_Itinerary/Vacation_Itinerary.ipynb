# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df.head(50)
# Out:
#     City_ID              City Country  Max Temp Current Description      Lat  \
# 0         6             Kapaa      US     78.78          few clouds  22.0752
# 1         8          Katsuura      JP     70.66    scattered clouds  35.1333
# 2        11              Hilo      US     75.27     overcast clouds  19.7297
# 3        12         Road Town      VG     78.89     overcast clouds  18.4167
# 4        20           Samarai      PG     80.71     overcast clouds -10.6167
# 5        21           Rikitea      PF     76.86          few clouds -23.1203
# 6        23            Atuona      PF     78.39    scattered clouds  -9.8000
# 7        24         Pemangkat      ID     86.18       broken clouds   1.1667
# 8        26      Port Hedland      AU     82.45       broken clouds -20.3167
# 9        37  Puerto Escondido      MX     80.87     overcast clouds  15.8500
# 10       40               Mao      ES     70.36           clear sky  39.8885
# 11       46             Fukue      JP     75.56       broken clouds  32.6881
# 12       49          Tay Ninh      VN     87.58     overcast clouds  11.3000
# 13       50             Dakar      SN     76.08     overcast clouds  14.6937
# 14       51          Souillac      MU     79.18          light rain -20.5167
# 15       52           Cayenne      GF     81.09          few clouds   4.9333
# 16       54          Victoria      HK     89.96       broken clouds  22.2855
# 17       56             Wajir      KE     80.56       broken clouds   1.7471
# 18       58            Wajima      JP     75.88          few clouds  37.4000
# 19       65            Helong      CN     81.61     overcast clouds  42.5397
# 20       69               Vao      NC     74.25       broken clouds -22.6667
# 21       73        Butaritari      KI     81.25          light rain   3.0707
# 22       74             Vaini      TO     78.96       broken clouds -21.2000
# 23       81     Saint-Georges      GD     78.48          few clouds  12.0564
# 24       83         Byron Bay      AU     71.71           clear sky -28.6500
# 25       94             Pecos      US     85.30           clear sky  31.4229
# 26       95        Cedar City      US     72.57           clear sky  37.6775
# 27       96       Bahia Honda      CU     76.51     overcast clouds  22.9036
# 28       98             Bilma      NE     87.55           clear sky  18.6853
# 29      100       Port-Gentil      GA     73.36          few clouds  -0.7193
# 30      102         Geraldton      AU     75.61           clear sky -28.7667
# 31      104     Villa Bruzual      VE     70.65     overcast clouds   9.3328
# 32      106            Kawalu      ID     88.84    scattered clouds  -7.3817
# 33      112     Wichita Falls      US     74.25           clear sky  33.9137
# 34      115             Korla      CN     86.67    scattered clouds  41.7597
# 35      116      San Patricio      US     80.49           clear sky  28.0170
# 36      120            Avarua      CK     75.25          light rain -21.2078
# 37      123              Hami      CN     89.20       broken clouds  42.8000
# 38      124   Bambous Virieux      MU     79.21          light rain -20.3428
# 39      130           Sakakah      SA     83.77           clear sky  29.9697
# 40      133         Namatanai      PG     83.30     overcast clouds  -3.6667
# 41      136            Amatan      MX     70.52     overcast clouds  17.3500
# 42      143            Faanui      PF     81.18           clear sky -16.4833
# 43      148        Porto Novo      BJ     78.62     overcast clouds   6.4965
# 44      149         Hithadhoo      MV     83.93       broken clouds  -0.6000
# 45      150           Bubaque      GW     78.98     overcast clouds  11.2833
# 46      153         Sinnamary      GF     76.95          few clouds   5.3833
# 47      157         Kavaratti      IN     82.80       broken clouds  10.5669
# 48      158              Faya      SA     75.31           clear sky  18.3851
# 49      159          Kirakira      SB     81.21    scattered clouds -10.4544
#
#          Lng                                      Hotel Name
# 0  -159.3190             Sheraton Kauai Coconut Beach Resort
# 1   140.3000                         Katsuura Hotel Mikazuki
# 2  -155.0900                             Hilo Hawaiian Hotel
# 3   -64.6167  ZINGARA 76ft Catamaran, full crew-all included
# 4   150.6667                                       Nuli Sapi
# 5  -134.9692                                 People ThankYou
# 6  -139.0333                                     Villa Enata
# 7   108.9667                                 Ramah Kost KITA
# 8   118.5667                             The Esplanade Hotel
# 9   -97.0667                   Aldea del Bazar Hotel and Spa
# 10    4.2658                                    ARTIEM Capri
# 11  128.8419         Goto Guesthouse Utojuku & SA Car Rental
# 12  106.1000                               Thanh Tuyền Hotel
# 13  -17.4441                                   Novotel Dakar
# 14   57.5167                     Shanti Maurice Resort & Spa
# 15  -52.3333                                 Hôtel Le Dronmi
# 16  114.1577                                    Mini Central
# 17   40.0573                 Al-bustan Hotel And Restaurant.
# 18  136.9000                            Wajiima Onsen Yashio
# 19  128.9972                                    Helong Hotel
# 20  167.4833                                 Hotel Kou-Bugny
# 21  172.7902                              Isles Sunset Lodge
# 22 -175.2000                             Keleti Beach Resort
# 23  -61.7485                   Radisson Grenada Beach Resort
# 24  153.6167                                 Backpackers Inn
# 25 -103.4932            Knights Inn & Suites Pecos Northeast
# 26 -113.0619                          Hampton Inn Cedar City
# 27  -83.1592                          Casa Gualberto - Deysi
# 28   12.9164                      Expeditions Ténére voyages
# 29    8.7815                              Fengshui Residence
# 30  114.6000                       Broadwater Mariner Resort
# 31  -69.1208                                    hotel italia
# 32  108.2082                                     West Jontor
# 33  -98.4934         Quality Inn & Suites Wichita Falls I-44
# 34   86.1469                                 Gulisitan Hotel
# 35  -97.5169                              Motel 6 Sinton, TX
# 36 -159.7750                                    Paradise Inn
# 37   93.4500                                Laoyutang Resort
# 38   57.7575                                  Casa Tia Villa
# 39   40.2064                   Fakhamat Al Orjoana Apartment
# 40  152.4333                           Seagulls Inn Namatani
# 41  -92.7500                                   Las gardenias
# 42 -151.7500              Bora-Bora Pearl Beach Resort & Spa
# 43    2.6036                         Tour Eiffel Hotel Benin
# 44   73.0833                               Scoop Guest House
# 45  -15.8333                              Casa Dora, Bubaque
# 46  -52.9500                  ALETHEIA Appartement Sinnamary
# 47   72.6420                   Hotels in Lakshadweep Islands
# 48   42.4509                              املاك خالد الشعشوع
# 49  161.9205                                    SanBiz Lodge

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == "Mount Pleasant"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Mount Pleasant"]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Cedar Park"]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "Naco"] 
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "West Wendover"]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_end["Lat"].to_numpy()[0], vacation_end["Lng"].to_numpy()[0]
stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

fig = gmaps.figure()
vacation_itinerary = gmaps.directions_layer(
        start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')

fig.add_layer(vacation_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID            City Country  Max Temp Current Description      Lat  \
# 0      593  Mount Pleasant      US     75.18          few clouds  32.7941
# 1      351      Cedar Park      US     79.90           clear sky  30.5052
# 2      210            Naco      MX     75.29           clear sky  31.3347
# 3      358   West Wendover      US     72.61    scattered clouds  40.7391
#
#         Lng                                         Hotel Name
# 0  -79.8626                        Best Western Patriots Point
# 1  -97.8203  La Quinta Inn & Suites by Wyndham Austin - Ced...
# 2 -109.9483                                     Motel Colonial
# 3 -114.0733                               Motel 6 Wendover, UT

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Weather</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig = gmaps.figure()
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
